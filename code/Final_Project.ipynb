# %% [markdown]
# This file is the code for the research of Alternative Dollar Auction Game: Modeling and Simulation Based on "Thirty-Six Stratagems" and Game Theory.

# %% [markdown]
# Here is install needed packages

# %%
pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# #Strategy class.
# - The following code defines a class called "Strategy" with various methods for different strategies in a game. The class uses the matplotlib.pyplot and random modules.
#
# - The class has several attributes including strategy, tell_the_truth, believe_the_word, persentage_pay_value_good1, persentage_pay_value_good2, tell_value_good1, tell_value_good2, and mark. The attributes are initialized in the constructor (__init__ method).
#
# ## The class methods are as follows:
#
# - defult_strategy: Sets the attribute values to their default values.
#
# - Winning_Strategems: Sets the attribute values based on the provided which parameter to represent winning strategies.
#
# - Enemy_Dealing_Stratagems: Sets the attribute values based on the provided which parameter to represent strategies for dealing with the enemy.
#
# - Offensive_Stratagems: Sets the attribute values based on the provided which parameter to represent offensive strategies.
#
# - Melee_Stratagems: Sets the attribute values based on the provided which parameter to represent melee strategies.
#
# - Combined_Stratagems: Sets the attribute values based on the provided which parameter to represent combined strategies.
#
# - Defeat_Stratagems: Sets the attribute values based on the provided which parameter to represent defeat strategies.
#
# - The code uses conditional statements (if and else) to determine the appropriate attribute values based on the given which parameter. The random.random() function is used to generate random values for certain attributes.
# ## Meaning of the marks:
# -  w0: Deceive the heavens to cross the sea
# -  w1: Besiege Wei to rescue Zhao
# -  w2: Wait at leisure while the enemy labors
# -  w3: Loot a burning house
# -  w4: Make a sound in the east, then strike in the west
# -  e0: Create something from nothing
# -  e1: Openly repair the gallery roads, but sneak through the passage of Chencang
# -  e2: Watch the fires burning across the river
# -  e3: Hide a knife behind a smile
# -  e4: Take the opportunity to pilfer a goat
# -  o0: Lure the tiger down the mountain
# -  o1: In order to capture, one must let loose
# -  o2: Defeat the enemy by capturing their chief
# -  m0: Remove the firewood from under the pot
# -  m1: Disturb the water and catch a fish
# -  m2: Slough off the cicada's golden shell
# -  m3: Shut the door to catch the thief
# -  c0: Replace the beams with rotten timbers
# -  c1: Remove the ladder when the enemy has ascended to the roof
# -  c2: Make the host and the guest exchange roles
# -  d0: The empty fort strategy
# -  d1: Inflict injury on oneself to win the enemy's trust
# -  d2: If all else fails, retreat

# %%
import matplotlib.pyplot as plt
import random as r
class Strategy:
  def __init__(self,tell_the_truth=True,believe_the_word=True):
    self.strategy=0
    self.tell_the_truth=tell_the_truth
    self.believe_the_word=believe_the_word
    self.persentage_pay_value_good1="half"
    self.persentage_pay_value_good2="half"
    self.tell_value_good1="half"
    self.tell_value_good2="half"
    self.mark=""
  def defult_strategy(self): 
    self.tell_the_truth=True
    self.believe_the_word=True
    self.persentage_pay_value_good1="half"
    self.persentage_pay_value_good2="half"
    self.mark="defult"
  def Winning_Strategems(self,which=0): 
    if which==0: 
      self.mark="w0"
      self.tell_the_truth=False 
      self.believe_the_word=False
      self.persentage_pay_value_good1="higher"
      self.persentage_pay_value_good2="higher"
      temp=r.random()
      if temp>=0.5:
        self.tell_value_good1="higher"
        self.tell_value_good2="lower"
        if temp>=0.75:
          self.tell_value_good2="zero"
      else:
        self.tell_value_good1="lower"
        self.tell_value_good2="higher"
        if temp<=0.25:
          self.tell_value_good1="zero"
    if which==1: 
      self.mark="w1"
      self.tell_the_truth=False 
      self.believe_the_word=True
      self.persentage_pay_value_good1="depend"
      self.persentage_pay_value_good2="depend"
      self.tell_value_good1="high"
      self.tell_value_good2="high"
    if which==2: 
      self.mark="w2"
      self.tell_the_truth=True
      self.believe_the_word=False
      self.persentage_pay_value_good1="equal+"
      self.persentage_pay_value_good2="equal+"
      self.tell_value_good1="zero"
      self.tell_value_good2="zero"
    if which==3: 
      self.mark="w3"
      self.tell_the_truth=False
      self.believe_the_word=False
      self.persentage_pay_value_good1="equal+"
      self.persentage_pay_value_good2="equal+"
      self.tell_value_good1="low"
      self.tell_value_good2="low"
    if which==4: 
      self.mark="w4"
      self.tell_the_truth=False
      self.believe_the_word=True
      temp=r.random()
      if temp>0.5:
        self.persentage_pay_value_good1="depend"
        self.persentage_pay_value_good2="depend"
        self.tell_value_good1="high"
        self.tell_value_good2="low"
      else:
        self.persentage_pay_value_good1="depend"
        self.persentage_pay_value_good2="depend"
        self.tell_value_good1="low"
        self.tell_value_good2="high"
    if which==5: 
      pass
  def Enemy_Dealing_Stratagems(self,which=0): 
    if which==0: 
      self.mark="e0"
      self.tell_the_truth=False
      self.believe_the_word=False
      self.persentage_pay_value_good1="low"
      self.persentage_pay_value_good2="low"
      self.tell_value_good1="equal"
      self.tell_value_good2="high"
    if which==1: 
      self.mark="e1"
      self.tell_the_truth=False
      self.believe_the_word=False
      self.persentage_pay_value_good1="high"
      self.persentage_pay_value_good2="high"
      self.tell_value_good1="low"
      self.tell_value_good2="low"
    if which==2: 
      self.mark="e2"
      self.tell_the_truth=False
      self.believe_the_word=True
      self.tell_value_good1="half"
      self.tell_value_good2="half"
      self.persentage_pay_value_good1="depend"
      self.persentage_pay_value_good2="depend"
    if which==3: 
      self.mark="e3"
      self.tell_the_truth=False
      self.believe_the_word=True
      temp=r.random()
      if temp>0.5:
        self.tell_value_good1="half"
        self.tell_value_good2="lower"
        self.persentage_pay_value_good1="depend"
        self.persentage_pay_value_good2="depend"
      else:
        self.tell_value_good1="lower"
        self.tell_value_good2="half"
        self.persentage_pay_value_good1="depend"
        self.persentage_pay_value_good2="depend"
    if which==4: 
      self.mark="e4"
      self.tell_the_truth=True
      self.believe_the_word=False
      self.persentage_pay_value_good1="half"
      self.persentage_pay_value_good2="half"
      self.tell_value_good1="half"
      self.tell_value_good2="half"
    if which==5: 
      pass
  def Offensive_Stratagems(self,which=0):
    if which==0:
      self.mark="o0"
      self.tell_the_truth=False
      self.believe_the_word=True
      temp=r.random()
      if temp>0.5:
        self.tell_value_good1="higher"
        self.tell_value_good2="half"
        self.persentage_pay_value_good1="depend"
        self.persentage_pay_value_good2="depend"
      else:
        self.tell_value_good1="half"
        self.tell_value_good2="higher"
        self.persentage_pay_value_good1="depend"
        self.persentage_pay_value_good2="depend"
    if which==1:
      self.mark="o1"
      self.tell_the_truth=False
      self.believe_the_word=False
      self.persentage_pay_value_good1="low"
      self.persentage_pay_value_good2="low"
      self.tell_value_good1="half"
      self.tell_value_good2="half"
    if which==2:
      self.mark="o2"
      self.tell_the_truth=True
      self.believe_the_word=False
      self.persentage_pay_value_good1="higher"
      self.persentage_pay_value_good2="lower"
      self.tell_value_good1="higher"
      self.tell_value_good2="lower"
    if which==3:
      pass
    if which==4:
      pass
    if which==5:
      pass
  def Melee_Stratagems(self,which):
    if which==0:
      self.mark="m0"
      self.tell_the_truth=False
      self.believe_the_word=False
      self.persentage_pay_value_good1="high"
      self.persentage_pay_value_good2="high"
      self.tell_value_good1="lower"
      self.tell_value_good2="lower"
    if which==1:
      self.mark="m1"
      self.tell_the_truth=False
      self.believe_the_word=False
      self.persentage_pay_value_good1="low"
      self.persentage_pay_value_good2="low"
      self.tell_value_good1="half"
      self.tell_value_good2="half"
    if which==2:
      self.mark="m2"
      self.tell_the_truth=False
      self.believe_the_word=False
      temp=r.random()
      if temp>0.5:
        self.persentage_pay_value_good1="lower"
        self.persentage_pay_value_good2="low"
        self.tell_value_good1="higher"
        self.tell_value_good2="lower"
      else:
        self.persentage_pay_value_good1="low"
        self.persentage_pay_value_good2="lower"
        self.tell_value_good1="lower"
        self.tell_value_good2="higher" 
    if which==3:
      self.mark="m3"
      self.tell_the_truth=False
      self.believe_the_word=False
      self.tell_value_good1="high"
      self.tell_value_good2="high"
      self.persentage_pay_value_good1="equal"
      self.persentage_pay_value_good2="equal"
    if which==4: 
      pass
    if which==5: 
      pass
  def Combined_Stratagems(self,which):
    if which==0:
      self.mark="c0"
      self.tell_the_truth=False
      self.believe_the_word=False
      temp=r.random()
      if temp>0.5:
        self.tell_value_good1="higher"
        self.tell_value_good2="lower"
        self.persentage_pay_value_good1="lower"
        self.persentage_pay_value_good2="higher"
      else:
        self.tell_value_good1="higher"
        self.tell_value_good2="lower"
        self.persentage_pay_value_good1="lower"
        self.persentage_pay_value_good2="higher"
    if which==1:
      self.mark="c1"
      self.tell_the_truth=False
      self.believe_the_word=True
      temp=r.random()
      if temp>0.5:
        self.tell_value_good1="higher"
        self.tell_value_good2="lower"
        self.persentage_pay_value_good1="depend"
        self.persentage_pay_value_good2="depend"
      else:
        self.tell_value_good1="higher"
        self.tell_value_good2="lower"
        self.persentage_pay_value_good1="depend"
        self.persentage_pay_value_good2="depend" 
    if which==2:
      self.mark="c2"
      self.believe_the_word=False
      self.tell_the_truth=False
      temp=r.random()
      if temp>0.5:
        self.tell_value_good1="higher"
        self.tell_value_good2="higher"
        self.persentage_pay_value_good1="lower"
        self.persentage_pay_value_good2="half"
      else:
        self.tell_value_good1="higher"
        self.tell_value_good2="higher"
        self.persentage_pay_value_good1="half"
        self.persentage_pay_value_good2="lower"

    if which==3:
      pass
    if which==4:
      pass
    if which==5:
      pass
  def Defeat_Stratagems(self,which):
    if which==0:
      self.mark="d0"
      self.tell_the_truth=False
      self.believe_the_word=False
      self.tell_value_good1="higher"
      self.tell_value_good2="higher"
      self.persentage_pay_value_good1="lower"
      self.persentage_pay_value_good2="lower"
    if which==1:
      self.mark="d1"
      self.tell_the_truth=False
      self.believe_the_word=False
      self.tell_value_good1="lower"
      self.tell_value_good2="lower"
      temp=r.random()
      if temp>0.5:
        self.persentage_pay_value_good1="higher"
        self.persentage_pay_value_good2="zero"
      else:
        self.persentage_pay_value_good1="zero"
        self.persentage_pay_value_good2="higher"
    if which==2:
      self.mark="d2"
      self.tell_the_truth=False
      self.believe_the_word=False
      self.tell_value_good1="higher"
      self.tell_value_good2="higher"
      self.persentage_pay_value_good1="zero"
      self.persentage_pay_value_good2="zero"
    if which==3:
      pass
    if which==4:
      pass
    if which==5:
      pass

# %% [markdown]
# This is the Content class, which contains two goods, one has default worth 4\$, and the other default worth 6\$

# %%
class Content:
    def __init__(self,good1=6,good2=4):
        self.good1=good1
        self.good2=good2

# %% [markdown]
# # Player Class
# - The code defines two classes, Player1 and Player2, for simulating a game between two players. Here is a breakdown of the code:
#
# ## Player1 Class:
#
# - The Player1 class represents the first player in the game.
# - The constructor method (__init__) initializes the player's attributes, such as their initial money, goods, stratagems, and various variables for keeping track of game information.
# - The player_move method handles the player's move based on whether the player is controlled by a human or an AI.<br>
# If the player is a human, it prompts the user for input regarding their strategy, goods, and payments.<br>
# If the player is an AI, it selects a random stratagem and executes it.<br>
# The which_stra method is used to execute the selected stratagem by calling the appropriate method from the Strategy class.<br>
# - The what_to_do method determines the player's actions based on the strategy used, including determining the actual and told values for goods and payments.
# ## Player2 Class:
# - The Player2 class represents the second player in the game. It has similar structure and functionality as the Player1 class, with some minor differences.
# ## Brief introduction
# In general, these classes provide a framework for simulating a game where two players make moves based on their chosen strategies and interact with goods and payments. However, some key parts of the code are missing, such as the definitions of the Content and Strategy classes, which are likely used by the Player1 and Player2 classes for handling game content and strategies. Without those missing pieces, it's difficult to provide a complete analysis of the code's functionality and behavior.

# %%
import random as r
class Player1:
    def __init__(self,given_stra="None",initial_money=10,is_ai=False,content=Content(),strategy=Strategy()):
        self.money=initial_money
        self.initial_money=initial_money
        self.goods=[]
        self.stratagems=["w0","w1","w2","w3","w4","e0","e1","e2","e3","o0","o1","o2","m0","m1","m2","m3","c0","c1","c2","d0","d1","d2"]
        self.stratagems_with_name=[["w0: Deceive the heavens to cross the sea","w1: Besiege Wei to rescue Zhao","w2: Wait at leisure while the enemy labors","w3: Loot a burning house","w4: Make a sound in the east, then strike in the west"],
                                   ["e0: Create something from nothing","e1: Openly repair the gallery roads, but sneak through the passage of Chencang","e2: Watch the fires burning across the river","e3: Hide a knife behind a smile", "e4: Take the opportunity to pilfer a goat"],
                                   ["o0: Lure the tiger down the mountain","o1: In order to capture, one must let loose","o2: Defeat the enemy by capturing their chief",],
                                   ["m0: Remove the firewood from under the pot","m1: Disturb the water and catch a fish","m2: Slough off the cicada's golden shell","m3: Shut the door to catch the thief"],
                                   ["c0: Replace the beams with rotten timbers","c1: Remove the ladder when the enemy has ascended to the roof","c2: Make the host and the guest exchange roles"],
                                   ["d0: The empty fort strategy","d1: Inflict injury on oneself to win the enemy's trust","d2: If all else fails, retreat"]]
        self.stratagems_use=[]
        self.strategyuse=""
        self.is_ai=is_ai
        self.content=content
        self.strategy=strategy
        self.tell_value_good1=0
        self.tell_value_good2=0
        self.persentage_pay_value_good1=0
        self.persentage_pay_value_good2=0
        self.actual_pay_value_good1=0
        self.actual_pay_value_good2=0
        self.human_believe_the_word=False
        self.tell_truth_time={"true":0,"false":0}
        self.section_persentage=[[0,30],[25,50],[50,80],[75,100]]
        self.ai_remember_opp_move=[]
        self.ai_consider_opp_money=initial_money
        self.ai_consider_opp_pay_good1=0
        self.ai_consider_opp_pay_good2=0
        self.use_stra="y"
        self.given_stra=given_stra
    def player_move(self):
        if self.is_ai==False:
            print("Your Current Money:",self.money)
            print("Your Now Have these goods",self.goods)
            print("Your Now Have these stratagems")
            temp=self.stratagems_with_name
            for i in range(0,len(temp)):
                for j in range(0,len(temp[i])):
                    print(temp[i][j])
            print("\n")
            self.use_stra = input("Are you going to use stratagems? (y/n):")
            if self.use_stra=="y":
                which_strate=input("Which stratagems you want to use?")
                self.stratagems_use.append(which_strate)
                print("You choose to use stratagems",which_strate)
                self.which_stra(which_strate)
                self.what_to_do()
            elif self.use_stra=="n":
                print("You choose not to use any of these stratagems")
                self.actual_pay_value_good1=float(input("How much do you want to for good1?"))
                self.actual_pay_value_good2=float(input("How much do you want to for good2?"))
                self.tell_value_good1=input("What do you want to tell your opponent about how much you want to pay for good1?")
                self.tell_value_good2=input("What do you want to tell your opponent about how much you want to pay good2?")
                if (self.actual_pay_value_good1!=self.tell_value_good1 or self.actual_pay_value_good2!=self.tell_value_good2):
                    self.tell_the_truth=False
                    self.tell_truth_time["false"]+=1
                else:
                    self.tell_the_truth=True
                    self.tell_truth_time["true"]+=1
        else:
            if self.given_stra=="None":
                self.ai_move()
            elif self.given_stra=="default":
                self.tell_value_good1=0.5*self.content.good1
                self.tell_value_good2=0.5*self.content.good2
                self.actual_pay_value_good1=0.5*self.content.good1
                self.actual_pay_value_good2=0.5*self.content.good2
                self.tell_the_truth=True
                self.tell_truth_time["true"]+=1
            else:
                self.stratagems_use.append(self.given_stra)
                self.strategyuse=self.given_stra
                self.which_stra(self.given_stra)
                self.what_to_do()
    def ai_move(self):
        which_strate=r.randint(0,21)
        self.stratagems_use.append(self.stratagems[which_strate])
        self.which_stra(self.stratagems[which_strate])
        self.strategyuse=self.stratagems[which_strate]
        self.what_to_do()
    def which_stra(self,which_stra):
        if which_stra=="w0":
            self.strategy.Winning_Strategems(0)
        if which_stra=="w1":
            self.strategy.Winning_Strategems(1)
        if which_stra=="w2":
            self.strategy.Winning_Strategems(2)
        if which_stra=="w3":
            self.strategy.Winning_Strategems(3)
        if which_stra=="w4":
            self.strategy.Winning_Strategems(4)
        if which_stra=="e0":
            self.strategy.Enemy_Dealing_Stratagems(0)
        if which_stra=="e1":
            self.strategy.Enemy_Dealing_Stratagems(1)
        if which_stra=="e2":
            self.strategy.Enemy_Dealing_Stratagems(2)
        if which_stra=="e3":
            self.strategy.Enemy_Dealing_Stratagems(3)
        if which_stra=="e4":
            self.strategy.Enemy_Dealing_Stratagems(4)
        if which_stra=="o0":
            self.strategy.Offensive_Stratagems(0)
        if which_stra=="o1":
            self.strategy.Offensive_Stratagems(1)
        if which_stra=="o2":
            self.strategy.Offensive_Stratagems(2)
        if which_stra=="m0":
            self.strategy.Melee_Stratagems(0)
        if which_stra=="m1":
            self.strategy.Melee_Stratagems(1)
        if which_stra=="m2":
            self.strategy.Melee_Stratagems(2)
        if which_stra=="m3":
            self.strategy.Melee_Stratagems(3)
        if which_stra=="c0":
            self.strategy.Combined_Stratagems(0)
        if which_stra=="c1":
            self.strategy.Combined_Stratagems(1)
        if which_stra=="c2":
            self.strategy.Combined_Stratagems(2)
        if which_stra=="d0":
            self.strategy.Defeat_Stratagems(0)
        if which_stra=="d1":
            self.strategy.Defeat_Stratagems(1)
        if which_stra=="d2":
            self.strategy.Defeat_Stratagems(2)
    def what_to_do(self):
        lower=self.section_persentage[0]
        low=self.section_persentage[1]
        high=self.section_persentage[2]
        higher=self.section_persentage[3]
        if self.strategy.tell_the_truth==True:
            self.tell_truth_time["true"]+=1
        else:
            self.tell_truth_time["false"]+=1
        lower1=r.randint(lower[0],lower[1])/100
        low1=r.randint(low[0],low[1])/100
        high1=r.randint(high[0],high[1])/100
        higher1=r.randint(higher[0],higher[1])/100
        equalplus1=1+r.randint(0,10)/100
        temp1=[0,lower1,low1,0.5,high1,higher1,1,equalplus1,10]#Last 10 means it depends
        temp1_1=["zero","lower","low","half","high","higher","equal","equal+","depend"]            
        lower2=r.randint(lower[0],lower[1])/100
        low2=r.randint(low[0],low[1])/100
        high2=r.randint(high[0],high[1])/100
        higher2=r.randint(higher[0],higher[1])/100
        equalplus2=1+r.randint(0,10)/100
        temp2=[0,lower2,low2,0.5,high2,higher2,1,equalplus2,10]#Last 10 means it depends
        temp2_2=["zero","lower","low","half","high","higher","equal","equal+","depend"]
        for i in range(0,len(temp1_1)):
            if self.strategy.tell_value_good1==temp1_1[i]:
                self.tell_value_good1=temp1[i]*self.content.good1
            if self.strategy.persentage_pay_value_good1==temp1_1[i]:
                self.persentage_pay_value_good1=temp1[i]
                self.actual_pay_value_good1=self.persentage_pay_value_good1*self.content.good1
        for i in range(0,len(temp2_2)):
            if self.strategy.tell_value_good2==temp2_2[i]:
                self.tell_value_good2=temp2[i]*self.content.good2
            if self.strategy.persentage_pay_value_good2==temp2_2[i]:
                self.persentage_pay_value_good2=temp2[i]
                self.actual_pay_value_good2=self.persentage_pay_value_good2*self.content.good2
import random as r
class Player2:
    def __init__(self,given_stra="None",initial_money=10,is_ai=False,content=Content(),strategy=Strategy()):
        self.money=initial_money
        self.initial_money=initial_money
        self.goods=[]
        self.stratagems=["w0","w1","w2","w3","w4","e0","e1","e2","e3","o0","o1","o2","m0","m1","m2","m3","c0","c1","c2","d0","d1","d2"]
        self.stratagems_with_name=[["w0: Deceive the heavens to cross the sea","w1: Besiege Wei to rescue Zhao","w2: Wait at leisure while the enemy labors","w3: Loot a burning house","w4: Make a sound in the east, then strike in the west"],
                                   ["e0: Create something from nothing","e1: Openly repair the gallery roads, but sneak through the passage of Chencang","e2: Watch the fires burning across the river","e3: Hide a knife behind a smile", "e4: Take the opportunity to pilfer a goat"],
                                   ["o0: Lure the tiger down the mountain","o1: In order to capture, one must let loose","o2: Defeat the enemy by capturing their chief",],
                                   ["m0: Remove the firewood from under the pot","m1: Disturb the water and catch a fish","m2: Slough off the cicada's golden shell","m3: Shut the door to catch the thief"],
                                   ["c0: Replace the beams with rotten timbers","c1: Remove the ladder when the enemy has ascended to the roof","c2: Make the host and the guest exchange roles"],
                                   ["d0: The empty fort strategy","d1: Inflict injury on oneself to win the enemy's trust","d2: If all else fails, retreat"]]
        self.stratagems_use=[]
        self.strategyuse=""
        self.is_ai=is_ai
        self.content=content
        self.strategy=strategy
        self.tell_value_good1=0
        self.tell_value_good2=0
        self.persentage_pay_value_good1=0
        self.persentage_pay_value_good2=0
        self.actual_pay_value_good1=0
        self.actual_pay_value_good2=0
        self.human_believe_the_word=False
        self.tell_truth_time={"true":0,"false":0}
        self.section_persentage=[[0,30],[25,50],[50,80],[75,100]]
        self.ai_remember_opp_move=[]
        self.ai_consider_opp_money=initial_money
        self.ai_consider_opp_pay_good1=0
        self.ai_consider_opp_pay_good2=0
        self.use_stra="y"
        self.given_stra=given_stra
    def player_move(self):
        if self.is_ai==False:
            print("Your Current Money:",self.money)
            print("Your Now Have these goods",self.goods)
            print("Your Now Have these stratagems")
            temp=self.stratagems_with_name
            for i in range(0,len(temp)):
                for j in range(0,len(temp[i])):
                    print(temp[i][j])
            print("\n")
            self.use_stra = input("Are you going to use stratagems? (y/n):")
            if self.use_stra=="y":
                which_strate=input("Which stratagems you want to use?")
                self.stratagems_use.append(which_strate)
                print("You choose to use stratagems",which_strate)
                self.which_stra(which_strate)
                self.what_to_do()
            elif self.use_stra=="n":
                print("You choose not to use any of these stratagems")
                self.actual_pay_value_good1=float(input("How much do you want to for good1?"))
                self.actual_pay_value_good2=float(input("How much do you want to for good2?"))
                self.tell_value_good1=input("What do you want to tell your opponent about how much you want to pay for good1?")
                self.tell_value_good2=input("What do you want to tell your opponent about how much you want to pay good2?")
                if (self.actual_pay_value_good1!=self.tell_value_good1 or self.actual_pay_value_good2!=self.tell_value_good2):
                    self.tell_the_truth=False
                    self.tell_truth_time["false"]+=1
                else:
                    self.tell_the_truth=True
                    self.tell_truth_time["true"]+=1
        else:
            if self.given_stra=="None":
                self.ai_move()
            elif self.given_stra=="default":
                self.tell_value_good1=0.5*self.content.good1
                self.tell_value_good2=0.5*self.content.good2
                self.actual_pay_value_good1=0.5*self.content.good1
                self.actual_pay_value_good2=0.5*self.content.good2
                self.tell_the_truth=True
                self.tell_truth_time["true"]+=1
            else:
                self.stratagems_use.append(self.given_stra)
                self.strategyuse=self.given_stra
                self.which_stra(self.given_stra)
                self.what_to_do()
    def ai_move(self):
        which_strate=r.randint(0,21)
        self.stratagems_use.append(self.stratagems[which_strate])
        self.which_stra(self.stratagems[which_strate])
        self.strategyuse=self.stratagems[which_strate]
        self.what_to_do()
    def which_stra(self,which_stra):
        if which_stra=="w0":
            self.strategy.Winning_Strategems(0)
        if which_stra=="w1":
            self.strategy.Winning_Strategems(1)
        if which_stra=="w2":
            self.strategy.Winning_Strategems(2)
        if which_stra=="w3":
            self.strategy.Winning_Strategems(3)
        if which_stra=="w4":
            self.strategy.Winning_Strategems(4)
        if which_stra=="e0":
            self.strategy.Enemy_Dealing_Stratagems(0)
        if which_stra=="e1":
            self.strategy.Enemy_Dealing_Stratagems(1)
        if which_stra=="e2":
            self.strategy.Enemy_Dealing_Stratagems(2)
        if which_stra=="e3":
            self.strategy.Enemy_Dealing_Stratagems(3)
        if which_stra=="e4":
            self.strategy.Enemy_Dealing_Stratagems(4)
        if which_stra=="o0":
            self.strategy.Offensive_Stratagems(0)
        if which_stra=="o1":
            self.strategy.Offensive_Stratagems(1)
        if which_stra=="o2":
            self.strategy.Offensive_Stratagems(2)
        if which_stra=="m0":
            self.strategy.Melee_Stratagems(0)
        if which_stra=="m1":
            self.strategy.Melee_Stratagems(1)
        if which_stra=="m2":
            self.strategy.Melee_Stratagems(2)
        if which_stra=="m3":
            self.strategy.Melee_Stratagems(3)
        if which_stra=="c0":
            self.strategy.Combined_Stratagems(0)
        if which_stra=="c1":
            self.strategy.Combined_Stratagems(1)
        if which_stra=="c2":
            self.strategy.Combined_Stratagems(2)
        if which_stra=="d0":
            self.strategy.Defeat_Stratagems(0)
        if which_stra=="d1":
            self.strategy.Defeat_Stratagems(1)
        if which_stra=="d2":
            self.strategy.Defeat_Stratagems(2)
    def what_to_do(self):
        lower=self.section_persentage[0]
        low=self.section_persentage[1]
        high=self.section_persentage[2]
        higher=self.section_persentage[3]
        if self.strategy.tell_the_truth==True:
            self.tell_truth_time["true"]+=1
        else:
            self.tell_truth_time["false"]+=1
        lower1=r.randint(lower[0],lower[1])/100
        low1=r.randint(low[0],low[1])/100
        high1=r.randint(high[0],high[1])/100
        higher1=r.randint(higher[0],higher[1])/100
        equalplus1=1+r.randint(0,10)/100
        temp1=[0,lower1,low1,0.5,high1,higher1,1,equalplus1,10]#Last 10 means it depends
        temp1_1=["zero","lower","low","half","high","higher","equal","equal+","depend"]            
        lower2=r.randint(lower[0],lower[1])/100
        low2=r.randint(low[0],low[1])/100
        high2=r.randint(high[0],high[1])/100
        higher2=r.randint(higher[0],higher[1])/100
        equalplus2=1+r.randint(0,10)/100
        temp2=[0,lower2,low2,0.5,high2,higher2,1,equalplus2,10]#Last 10 means it depends
        temp2_2=["zero","lower","low","half","high","higher","equal","equal+","depend"]
        for i in range(0,len(temp1_1)):
            if self.strategy.tell_value_good1==temp1_1[i]:
                self.tell_value_good1=temp1[i]*self.content.good1
            if self.strategy.persentage_pay_value_good1==temp1_1[i]:
                self.persentage_pay_value_good1=temp1[i]
                self.actual_pay_value_good1=self.persentage_pay_value_good1*self.content.good1
        for i in range(0,len(temp2_2)):
            if self.strategy.tell_value_good2==temp2_2[i]:
                self.tell_value_good2=temp2[i]*self.content.good2
            if self.strategy.persentage_pay_value_good2==temp2_2[i]:
                self.persentage_pay_value_good2=temp2[i]
                self.actual_pay_value_good2=self.persentage_pay_value_good2*self.content.good2

# %% [markdown]
# # Game Class:
# ## The Game class represents the game being played.
# - The constructor method (__init__) initializes the game's attributes, including the players, a dictionary for tracking the winner, a dictionary for tracking the winning strategies, and other variables related to game statistics.
# - The play_r1 method simulates a round of the game by executing the moves of both players, resolving the moves' outcomes, and updating the game state.
# The who_is_winning method determines the winner based on the players' money and updates the win count and winning strategy count accordingly.
# - The change_money_goods method calculates the changes in players' money and goods based on the values of goods and payments.
# - The depend_move method handles the case when one player's payment depends on the other player's value, by setting the actual payment values accordingly.
# - The human_depend_move method is called when one player is human-controlled and prompts the user for input regarding their payments, based on the strategy and information provided by the opponent.
# ## Brief introduction:
# In general, the Game class provides the functionality to simulate and track the progress of the game between two players, including updating their money and goods based on their moves and determining the winner. However, it appears that the code provided is missing the definitions for the Player1, Player2, Content, and Strategy classes, which are likely used within the Game class. Without those missing pieces, it's challenging to fully understand the complete functionality and behavior of the code.

# %%
import random as r
class Game:
    def __init__(self,p1=Player1(is_ai=True),p2=Player2(is_ai=True),is_show=False,decrease_rate=0.3):
        self.mark=0
        self.p1=p1
        self.p2=p2
        self.p1_1=p1
        self.p2_2=p2
        self.winner={"p1":0,"p2":0}
        self.wining_stra=[]
        self.wining_stra={"w0":0,"w1":0,"w2":0,"w3":0,"w4":0,"e0":0,"e1":0,"e2":0,"e3":0,"o0":0,"o1":0,"o2":0,"m0":0,"m1":0,"m2":0,"m3":0,"c0":0,"c1":0,"c2":0,"d0":0,"d1":0,"d2":0}
        self.is_show=is_show
        self.decresae_rate=decrease_rate
        self.real_winning_p1={"true":0,"false":0}
        self.real_winning_p2={"true":0,"false":0}
    def play_r1(self):
        self.p1.player_move()
        self.p2.player_move()
        self.depend_move()
        self.change_money_goods()
        self.who_is_winning()
    def who_is_winning(self):
        if self.p1.money>=self.p2.money:
            self.winner["p1"]+=1
            if self.p1.given_stra=="default":
                pass
            else:
                self.wining_stra[self.p1.strategyuse]+=1
            if self.p1.money<self.p1.initial_money:
                self.real_winning_p1["false"]+=1
            else:
                self.real_winning_p1["true"]+=1
        elif self.p1.money<self.p2.money:
            self.winner["p2"]+=1
            if self.p2.given_stra=="default":
                pass
            else:
                self.wining_stra[self.p2.strategyuse]+=1
            if self.p2.money<self.p2.initial_money:
                self.real_winning_p2["false"]+=1
            else:
                self.real_winning_p2["true"]+=1
    def change_money_goods(self):
        if self.p1.actual_pay_value_good1>=self.p2.actual_pay_value_good1:
            self.p1.money=self.p1.money-self.p1.actual_pay_value_good1+self.p1.content.good1
            self.p2.money-=self.decresae_rate*self.p2.actual_pay_value_good1
        else:
            self.p2.money=self.p2.money-self.p2.actual_pay_value_good1+self.p2.content.good1
            self.p1.money-=self.decresae_rate*self.p1.actual_pay_value_good1
        if self.p1.actual_pay_value_good2>=self.p2.actual_pay_value_good2:
            self.p1.money=self.p1.money-self.p1.actual_pay_value_good2+self.p1.content.good2
            self.p2.money-=self.decresae_rate*self.p2.actual_pay_value_good2
        else:
            self.p2.money=self.p2.money-self.p2.actual_pay_value_good2+self.p2.content.good2
            self.p1.money-=self.decresae_rate*self.p1.actual_pay_value_good2
    def depend_move(self):
        if self.p1.strategy.persentage_pay_value_good1=="depend":
            self.p1.actual_pay_value_good1=self.p2.tell_value_good1+r.randint(0,10)/100
        if self.p1.strategy.persentage_pay_value_good2=="depend":
            self.p1.actual_pay_value_good2=self.p2.tell_value_good2+r.randint(0,10)/100
        if self.p2.strategy.persentage_pay_value_good1=="depend":
            self.p2.actual_pay_value_good1=self.p1.tell_value_good1+r.randint(0,10)/100
        if self.p2.strategy.persentage_pay_value_good2=="depend":
            self.p2.actual_pay_value_good2=self.p1.tell_value_good2+r.randint(0,10)/100
    def human_depend_move(self):
        if self.p1.is_ai==False:
            if self.p1.use_stra=="y":
                if self.p1.strategy.believe_the_word:
                    print(self.p2.tell_value_good1)
                    print(self.p2.tell_value_good2)
                    if self.p1.strategy.persentage_pay_value_good1=="depend":
                        self.p1.actual_pay_value_good1=input("How much you want to pay for good1:")
                    if self.p1.strategy.persentage_pay_value_good2=="depend":
                        self.p1.actual_pay_value_good2=input("How much you want to pay for good2:")

# %%
content=Content(10,0)
r.seed(0)
p3=Player1(is_ai=True,content=content)
p4=Player2(is_ai=True,content=content)
g0=Game(p3,p4,True,1)
a=[]
b=[]
c=[]
d=[]
e=[]
i=0
for key in g0.wining_stra:
    a.append([])
    b.append([])
    a[i].append(key)
    b[i].append(key)
    for key2 in g0.wining_stra:
        a[i].append(0)
        b[i].append(0)
    i+=1
i=0
for key in g0.wining_stra:
    j=1
    for key2 in g0.wining_stra:
        for k in range(100):
            p1=Player1(key,is_ai=True,content=content)
            p2=Player2("default",is_ai=True,content=content)
            g=Game(p1,p2,False,1)
            g.play_r1()
            a[i][j]+=g.winner["p1"]
            b[i][j]+=g.real_winning_p1["true"]
        j+=1
    i+=1
d=[]
e=[]
for i in range(0,len(a)):
    a[i]=a[i][1:]
    b[i]=b[i][1:]
    d.append(sum(a[i])/100)
    e.append(sum(b[i])/100)
plt.plot(g.p1.stratagems,d,label="Winning times")
plt.plot(g.p1.stratagems,e,label="Real Winning times")
plt.title("Winning times and Real Winning times when p1 applying Thirty-Six Stratagems and p2 is defult, content=(10,0)")
plt.xlabel("stratagems")
plt.ylabel("times")
plt.legend()
plt.show()
a1=[]
b1=[]
for i in range(0,len(d)):
  a1.append(d[i])
for i in range(0,len(e)):
  b1.append(e[i])

# %%
content=Content(6,4)
r.seed(0)
p3=Player1(is_ai=True,content=content)
p4=Player2(is_ai=True,content=content)
g0=Game(p3,p4,True,1)
a=[]
b=[]
c=[]
d=[]
e=[]
i=0
for key in g0.wining_stra:
    a.append([])
    b.append([])
    a[i].append(key)
    b[i].append(key)
    for key2 in g0.wining_stra:
        a[i].append(0)
        b[i].append(0)
    i+=1
i=0
for key in g0.wining_stra:
    j=1
    for key2 in g0.wining_stra:
        for k in range(100):
            p1=Player1(key,is_ai=True,content=content)
            p2=Player2("default",is_ai=True,content=content)
            g=Game(p1,p2,False,1)
            g.play_r1()
            a[i][j]+=g.winner["p1"]
            b[i][j]+=g.real_winning_p1["true"]
        j+=1
    i+=1
d=[]
e=[]
for i in range(0,len(a)):
    a[i]=a[i][1:]
    b[i]=b[i][1:]
    d.append(sum(a[i]))
    e.append(sum(b[i]))
plt.plot(g.p1.stratagems,d,label="Winning times")
plt.plot(g.p1.stratagems,e,label="Real Winning times")
plt.title("Winning times and Real Winning times when p1 applying Thirty-Six Stratagems and p2 is defult, content=(6,4)")
plt.xlabel("stratagems")
plt.ylabel("times")
plt.legend()
plt.show()
a2=[]
b2=[]
for i in range(0,len(d)):
  a2.append(d[i])
for i in range(0,len(e)):
  b2.append(e[i])

# %%
content=Content(10,0)
r.seed(0)
p3=Player1(is_ai=True,content=content)
p4=Player2(is_ai=True,content=content)
g0=Game(p3,p4,True,1)
a=[]
b=[]
c=[]
d=[]
e=[]
i=0
for key in g0.wining_stra:
    a.append([])
    b.append([])
    a[i].append(key)
    b[i].append(key)
    for key2 in g0.wining_stra:
        a[i].append(0)
        b[i].append(0)
    i+=1
i=0
for key in g0.wining_stra:
    j=1
    for key2 in g0.wining_stra:
        for k in range(100):
            p1=Player1(key,is_ai=True,content=content)
            p2=Player2(key2,is_ai=True,content=content)
            g=Game(p1,p2,False,1)
            g.play_r1()
            a[i][j]+=g.winner["p1"]
            b[i][j]+=g.real_winning_p1["true"]
        j+=1
    i+=1
for i in range(0,len(a)):
    a[i]=a[i][1:]
    b[i]=b[i][1:]
    d.append(sum(a[i]))
    e.append(sum(b[i]))
plt.plot(g.p1.stratagems,d,label="Winning times")
plt.plot(g.p1.stratagems,e,label="Real Winning times")
plt.title("Winning times and Real Winning times when p1 and p2 applying Thirty-Six Stratagems, content=(10,0)")
plt.xlabel("stratagems")
plt.ylabel("times")
plt.legend()
plt.show()
a3=[]
b3=[]
for i in range(0,len(d)):
  a3.append(d[i])
for i in range(0,len(e)):
  b3.append(e[i])

# %%
content=Content(6,4)
r.seed(0)
p3=Player1(is_ai=True,content=content)
p4=Player2(is_ai=True,content=content)
g0=Game(p3,p4,True,1)
a=[]
b=[]
c=[]
d=[]
e=[]
i=0
for key in g0.wining_stra:
    a.append([])
    b.append([])
    a[i].append(key)
    b[i].append(key)
    for key2 in g0.wining_stra:
        a[i].append(0)
        b[i].append(0)
    i+=1
i=0
for key in g0.wining_stra:
    j=1
    for key2 in g0.wining_stra:
        for k in range(100):
            p1=Player1(key,is_ai=True,content=content)
            p2=Player2(key2,is_ai=True,content=content)
            g=Game(p1,p2,False,1)
            g.play_r1()
            a[i][j]+=g.winner["p1"]
            b[i][j]+=g.real_winning_p1["true"]
        j+=1
    i+=1
for i in range(0,len(a)):
    a[i]=a[i][1:]
    b[i]=b[i][1:]
    d.append(sum(a[i]))
    e.append(sum(b[i]))
plt.plot(g.p1.stratagems,d,label="Winning times")
plt.plot(g.p1.stratagems,e,label="Real Winning times")
plt.title("Winning times and Real Winning times when p1 and p2 applying Thirty-Six Stratagems, content=(6,4)")
plt.xlabel("stratagems")
plt.ylabel("times")
plt.legend()
plt.show()
a4=[]
b4=[]
for i in range(0,len(d)):
  a4.append(d[i])
for i in range(0,len(e)):
  b4.append(e[i])

# %% [markdown]
# # Results
# - The above graphs are the result of the simulation.
# ## Analysis of the result:
# - In the simulation, we observe that strategies w2 and w3 exhibit the highest winning rates but the lowest real winning rates. This outcome is achieved by employing a strategy of paying more money than the original value of the goods, thereby maximizing the chances of winning.
# - However, when the content value is modified to involve splitting one good into two separate goods, we observe a decrease in the winning rates of w2 and w3. Simultaneously, the winning rates of other strategies increase, resulting in a higher real winning rate overall.
# - This reorganization aims to present the information in a clearer and more coherent manner, emphasizing the key points regarding the proposition, the simulation results, and the impact of changing the content value on different strategies' winning rates and real winning rates.
# ## Conclusion:
# - Paying a higher value increases the probability of winning the game: The code suggests that players who pay a higher value for goods have a higher chance of winning. This implies that investing more money in goods can potentially lead to a favorable outcome. However, it's important to note that paying a higher value also carries a higher risk of losing value. Players need to find a balance between paying enough to increase their winning probability and avoiding excessive losses.
# - Splitting action goods can lead to a more complex situation and reduce damage from irrational opponent options: The code indicates that players have the option to split their actions among different goods. This strategy can make the game more intricate by introducing multiple variables for opponents to consider. It can also serve as a defensive measure against opponents' unpredictable moves, minimizing the impact of their irrational decisions. By diversifying their actions, players can increase their chances of success and mitigate potential losses.
